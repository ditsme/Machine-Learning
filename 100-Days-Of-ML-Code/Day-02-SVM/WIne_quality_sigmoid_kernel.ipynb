# %%
#Importing dependencies
import numpy as np
import pandas as pd
import matplotlib as plt
from google.colab import files
uploaded = files.upload()

wine_data=pd.read_csv("wine.csv")
x=wine_data.drop(['quality','volatile acidity','density','pH','sulphates','free sulfur dioxide','total sulfur dioxide'],axis=1)
y=wine_data['quality']
from sklearn.cross_validation import train_test_split
#train and test data split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 1)
from sklearn.svm import SVC

#"svm_clf" is our model 
svm_clf=SVC(kernel='sigmoid')#sigmoidal kernel
#fitting our data in svm model
svm_clf.fit(x_train,y_train)
#making predictions
pred=svm_clf.predict(x_test)
from sklearn.metrics import classification_report
classification_report(y_test,pred)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred)*100
# Out:
#      <input type="file" id="files-528ea698-1be5-4573-a8c3-4da965aaa4ff" name="files[]" multiple disabled />
#      <output id="result-528ea698-1be5-4573-a8c3-4da965aaa4ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wine.csv to wine (14).csv
# /usr/local/lib/python3.6/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 42.21388367729831
